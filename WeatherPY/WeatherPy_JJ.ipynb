# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#API CALL URL = http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID={YOUR API KEY}
base_url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
weather_api_key = "1c8babe22822ec7715d3f85b5b6dcd85"
url = base_url + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=1c8babe22822ec7715d3f85b5b6dcd85'

# %%
# Make call
response = requests.get(url)
weather_json = response.json()
weather_json
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1592697600,
#    'main': {'temp': 290.17,
#     'feels_like': 286.95,
#     'temp_min': 289.29,
#     'temp_max': 290.17,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1000,
#     'humidity': 68,
#     'temp_kf': 0.88},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 77},
#    'wind': {'speed': 5.09, 'deg': 63},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-21 00:00:00'},
#   {'dt': 1592708400,
#    'main': {'temp': 288.82,
#     'feels_like': 284.8,
#     'temp_min': 288.22,
#     'temp_max': 288.82,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1000,
#     'humidity': 61,
#     'temp_kf': 0.6},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 5.14, 'deg': 63},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-21 03:00:00'},
#   {'dt': 1592719200,
#    'main': {'temp': 290,
#     'feels_like': 285.72,
#     'temp_min': 289.93,
#     'temp_max': 290,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 54,
#     'temp_kf': 0.07},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 5.27, 'deg': 60},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-21 06:00:00'},
#   {'dt': 1592730000,
#    'main': {'temp': 290.52,
#     'feels_like': 286.34,
#     'temp_min': 290.52,
#     'temp_max': 290.52,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1002,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 5.02, 'deg': 64},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-21 09:00:00'},
#   {'dt': 1592740800,
#    'main': {'temp': 292.73,
#     'feels_like': 289.9,
#     'temp_min': 292.73,
#     'temp_max': 292.73,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1002,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 2.93, 'deg': 90},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-21 12:00:00'},
#   {'dt': 1592751600,
#    'main': {'temp': 294.06,
#     'feels_like': 290.34,
#     'temp_min': 294.06,
#     'temp_max': 294.06,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 4.48, 'deg': 74},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-21 15:00:00'},
#   {'dt': 1592762400,
#    'main': {'temp': 290.72,
#     'feels_like': 287.32,
#     'temp_min': 290.72,
#     'temp_max': 290.72,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1002,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 4.34, 'deg': 70},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-21 18:00:00'},
#   {'dt': 1592773200,
#    'main': {'temp': 288.55,
#     'feels_like': 285.57,
#     'temp_min': 288.55,
#     'temp_max': 288.55,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1002,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.64, 'deg': 74},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-21 21:00:00'},
#   {'dt': 1592784000,
#    'main': {'temp': 286.83,
#     'feels_like': 284.28,
#     'temp_min': 286.83,
#     'temp_max': 286.83,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1003,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.86, 'deg': 86},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-22 00:00:00'},
#   {'dt': 1592794800,
#    'main': {'temp': 287.16,
#     'feels_like': 284.49,
#     'temp_min': 287.16,
#     'temp_max': 287.16,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1002,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.84, 'deg': 98},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-22 03:00:00'},
#   {'dt': 1592805600,
#    'main': {'temp': 291.11,
#     'feels_like': 288.39,
#     'temp_min': 291.11,
#     'temp_max': 291.11,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1003,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.92, 'deg': 102},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-22 06:00:00'},
#   {'dt': 1592816400,
#    'main': {'temp': 294.6,
#     'feels_like': 291.12,
#     'temp_min': 294.6,
#     'temp_max': 294.6,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1002,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.34, 'deg': 107},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-22 09:00:00'},
#   {'dt': 1592827200,
#    'main': {'temp': 295.91,
#     'feels_like': 292.63,
#     'temp_min': 295.91,
#     'temp_max': 295.91,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1002,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 3.14, 'deg': 137},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-22 12:00:00'},
#   {'dt': 1592838000,
#    'main': {'temp': 294.96,
#     'feels_like': 292.05,
#     'temp_min': 294.96,
#     'temp_max': 294.96,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.24, 'deg': 161},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-22 15:00:00'},
#   {'dt': 1592848800,
#    'main': {'temp': 292.47,
#     'feels_like': 290.87,
#     'temp_min': 292.47,
#     'temp_max': 292.47,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.73, 'deg': 184},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-22 18:00:00'},
#   {'dt': 1592859600,
#    'main': {'temp': 290.62,
#     'feels_like': 289.76,
#     'temp_min': 290.62,
#     'temp_max': 290.62,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.05, 'deg': 129},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-22 21:00:00'},
#   {'dt': 1592870400,
#    'main': {'temp': 288.96,
#     'feels_like': 288,
#     'temp_min': 288.96,
#     'temp_max': 288.96,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 1.32, 'deg': 106},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-23 00:00:00'},
#   {'dt': 1592881200,
#    'main': {'temp': 289.28,
#     'feels_like': 288.03,
#     'temp_min': 289.28,
#     'temp_max': 289.28,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 1.59, 'deg': 90},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-23 03:00:00'},
#   {'dt': 1592892000,
#    'main': {'temp': 292.8,
#     'feels_like': 291.12,
#     'temp_min': 292.8,
#     'temp_max': 292.8,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.96, 'deg': 103},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-23 06:00:00'},
#   {'dt': 1592902800,
#    'main': {'temp': 296.31,
#     'feels_like': 294.11,
#     'temp_min': 296.31,
#     'temp_max': 296.31,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1002,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 2.36, 'deg': 83},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-23 09:00:00'},
#   {'dt': 1592913600,
#    'main': {'temp': 297.21,
#     'feels_like': 295.09,
#     'temp_min': 297.21,
#     'temp_max': 297.21,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 71},
#    'wind': {'speed': 1.82, 'deg': 50},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-23 12:00:00'},
#   {'dt': 1592924400,
#    'main': {'temp': 296.24,
#     'feels_like': 293.3,
#     'temp_min': 296.24,
#     'temp_max': 296.24,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 3.4, 'deg': 23},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-23 15:00:00'},
#   {'dt': 1592935200,
#    'main': {'temp': 293.44,
#     'feels_like': 290.76,
#     'temp_min': 293.44,
#     'temp_max': 293.44,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 3.26, 'deg': 35},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-23 18:00:00'},
#   {'dt': 1592946000,
#    'main': {'temp': 290.94,
#     'feels_like': 289.22,
#     'temp_min': 290.94,
#     'temp_max': 290.94,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1001,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.92, 'deg': 22},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-23 21:00:00'},
#   {'dt': 1592956800,
#    'main': {'temp': 290.02,
#     'feels_like': 288.07,
#     'temp_min': 290.02,
#     'temp_max': 290.02,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1002,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.05, 'deg': 329},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-24 00:00:00'},
#   {'dt': 1592967600,
#    'main': {'temp': 289.96,
#     'feels_like': 287.04,
#     'temp_min': 289.96,
#     'temp_max': 289.96,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1002,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 4.04, 'deg': 3},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 03:00:00'},
#   {'dt': 1592978400,
#    'main': {'temp': 294.3,
#     'feels_like': 289.88,
#     'temp_min': 294.3,
#     'temp_max': 294.3,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1003,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.44, 'deg': 19},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 06:00:00'},
#   {'dt': 1592989200,
#    'main': {'temp': 296.68,
#     'feels_like': 291.36,
#     'temp_min': 296.68,
#     'temp_max': 296.68,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1004,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.84, 'deg': 9},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 09:00:00'},
#   {'dt': 1593000000,
#    'main': {'temp': 296.78,
#     'feels_like': 291.28,
#     'temp_min': 296.78,
#     'temp_max': 296.78,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1005,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 6.12, 'deg': 0},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 12:00:00'},
#   {'dt': 1593010800,
#    'main': {'temp': 294.49,
#     'feels_like': 288.68,
#     'temp_min': 294.49,
#     'temp_max': 294.49,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1006,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 6.29, 'deg': 5},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 15:00:00'},
#   {'dt': 1593021600,
#    'main': {'temp': 290.51,
#     'feels_like': 284.79,
#     'temp_min': 290.51,
#     'temp_max': 290.51,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1007,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.82, 'deg': 19},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 18:00:00'},
#   {'dt': 1593032400,
#    'main': {'temp': 288.19,
#     'feels_like': 283.59,
#     'temp_min': 288.19,
#     'temp_max': 288.19,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1008,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.15, 'deg': 24},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-24 21:00:00'},
#   {'dt': 1593043200,
#    'main': {'temp': 286.48,
#     'feels_like': 283.11,
#     'temp_min': 286.48,
#     'temp_max': 286.48,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1009,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.77, 'deg': 11},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-25 00:00:00'},
#   {'dt': 1593054000,
#    'main': {'temp': 286.93,
#     'feels_like': 283.55,
#     'temp_min': 286.93,
#     'temp_max': 286.93,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1010,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 2.82, 'deg': 359},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 03:00:00'},
#   {'dt': 1593064800,
#    'main': {'temp': 291.06,
#     'feels_like': 286.4,
#     'temp_min': 291.06,
#     'temp_max': 291.06,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1010,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 4.23, 'deg': 359},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 06:00:00'},
#   {'dt': 1593075600,
#    'main': {'temp': 293.61,
#     'feels_like': 288.59,
#     'temp_min': 293.61,
#     'temp_max': 293.61,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1010,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 59},
#    'wind': {'speed': 4.74, 'deg': 7},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 09:00:00'},
#   {'dt': 1593086400,
#    'main': {'temp': 295.74,
#     'feels_like': 291.96,
#     'temp_min': 295.74,
#     'temp_max': 295.74,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1009,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 41},
#    'wind': {'speed': 3.81, 'deg': 348},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 12:00:00'},
#   {'dt': 1593097200,
#    'main': {'temp': 296.19,
#     'feels_like': 292.77,
#     'temp_min': 296.19,
#     'temp_max': 296.19,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1009,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 4.07, 'deg': 321},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 15:00:00'},
#   {'dt': 1593108000,
#    'main': {'temp': 293.97,
#     'feels_like': 290.85,
#     'temp_min': 293.97,
#     'temp_max': 293.97,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1008,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 4.29, 'deg': 291},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 18:00:00'},
#   {'dt': 1593118800,
#    'main': {'temp': 293,
#     'feels_like': 290.75,
#     'temp_min': 293,
#     'temp_max': 293,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1008,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.14, 'deg': 295},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-25 21:00:00'}],
#  'city': {'id': 524901,
#   'name': 'Moscow',
#   'coord': {'lat': 55.7522, 'lon': 37.6156},
#   'country': 'RU',
#   'timezone': 10800,
#   'sunrise': 1592700279,
#   'sunset': 1592763482}}

# %%
# print(json.dumps(weather_json, indent=4, sort_keys=True))
# print location
json.dumps(weather_json, indent=4, sort_keys=True)
print(weather_json["city"]['name'])
# Out:
# Bac Lieu

# %%
# Per isntructions - For final notebook, perform a weather check on each of... 
# ...the cities using a series of successive API calls
# Create empty lists to hold response information
city_id = []
city_name = []
cloudiness = []
country = []
lat = []
lng = []
date = []
max_temp = []
humidity = []
wind_speed = []
count = 0

# Loop through city list and request data from each city for the variables above, print N/A for those not found
for city in cities:
    response = requests.get(url + "&q=" + city + "&units=Imperial")
    weather_json = response.json()
    try:
        city_id.append(weather_json['city']['id'])
        city_name.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        date.append(weather_json['list'][0]['dt'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"City {count} | {city}")
    except:
        print("Record n/a") 
        pass
        
print("Complete!")
# Out:
# City 1 | bluff
# City 2 | kankan
# Record n/a
# City 3 | olafsvik
# Record n/a
# Record n/a
# City 4 | kothapet
# City 5 | rikitea
# City 6 | atuona
# City 7 | cidreira
# City 8 | punta arenas
# City 9 | aklavik
# City 10 | upernavik
# City 11 | jamestown
# City 12 | qaanaaq
# City 13 | airai
# City 14 | basco
# City 15 | alice springs
# City 16 | hovd
# City 17 | catumbela
# City 18 | kahului
# City 19 | da nang
# Record n/a
# City 20 | moura
# City 21 | tasiilaq
# City 22 | kapaa
# City 23 | visnes
# City 24 | ushuaia
# City 25 | busselton
# City 26 | waldkirch
# City 27 | djougou
# City 28 | chuy
# City 29 | souillac
# City 30 | haines junction
# Record n/a
# City 31 | high rock
# City 32 | labuhan
# City 33 | sabang
# City 34 | rongcheng
# City 35 | stepnogorsk
# City 36 | parrita
# City 37 | chitipa
# City 38 | jurm
# City 39 | east london
# City 40 | abha
# City 41 | carnarvon
# City 42 | esperance
# City 43 | xuddur
# City 44 | nouadhibou
# City 45 | bredasdorp
# City 46 | xai-xai
# City 47 | arraial do cabo
# City 48 | avera
# City 49 | thompson
# City 50 | khasan
# City 51 | nemuro
# City 52 | hilo
# City 53 | cape town
# City 54 | bilibino
# City 55 | iralaya
# Record n/a
# City 56 | luce
# City 57 | bambous virieux
# City 58 | caborca
# City 59 | sinnamary
# City 60 | saint-philippe
# City 61 | albany
# City 62 | saskylakh
# Record n/a
# City 63 | hobyo
# City 64 | hithadhoo
# City 65 | vila
# City 66 | barrow
# City 67 | chokurdakh
# City 68 | shache
# City 69 | panormos
# City 70 | ushtobe
# City 71 | dikson
# City 72 | mancheral
# City 73 | butaritari
# City 74 | hirara
# City 75 | torbay
# City 76 | kodiak
# City 77 | strezhevoy
# City 78 | mataura
# City 79 | hasaki
# City 80 | bafra
# Record n/a
# City 81 | praia
# City 82 | port elizabeth
# City 83 | mahebourg
# Record n/a
# City 84 | narsaq
# City 85 | leningradskiy
# City 86 | yeniseysk
# City 87 | mount gambier
# Record n/a
# City 88 | nikolskoye
# City 89 | goderich
# City 90 | taguatinga
# City 91 | aswan
# City 92 | puerto ayora
# City 93 | camargo
# City 94 | vila velha
# City 95 | escalerillas
# City 96 | bethel
# City 97 | xuanhua
# City 98 | hobart
# Record n/a
# City 99 | atherton
# City 100 | norman wells
# City 101 | pocatello
# City 102 | reims
# City 103 | hailar
# City 104 | linjiang
# Record n/a
# City 105 | mount isa
# City 106 | port alfred
# City 107 | longyearbyen
# City 108 | yellowknife
# City 109 | payo
# Record n/a
# City 110 | vila franca do campo
# City 111 | tezu
# City 112 | kintampo
# Record n/a
# City 113 | lorengau
# City 114 | pereira barreto
# City 115 | mar del plata
# City 116 | vaini
# City 117 | shenjiamen
# City 118 | kamenka
# City 119 | talavera de la reina
# City 120 | mishelevka
# City 121 | nara
# City 122 | cherskiy
# City 123 | cayenne
# Record n/a
# City 124 | vila do maio
# City 125 | jalu
# City 126 | vilyuysk
# Record n/a
# City 127 | bandarbeyla
# City 128 | waipawa
# City 129 | salalah
# City 130 | comodoro rivadavia
# City 131 | miri
# City 132 | saldanha
# City 133 | luderitz
# City 134 | clyde river
# City 135 | dingle
# City 136 | sao joao da barra
# City 137 | nome
# City 138 | ballina
# City 139 | north myrtle beach
# City 140 | yar-sale
# City 141 | minab
# City 142 | beatrice
# City 143 | atagay
# City 144 | keti bandar
# City 145 | hermanus
# City 146 | caucaia
# City 147 | kenai
# City 148 | san ignacio
# City 149 | kingaroy
# City 150 | sao filipe
# City 151 | porto novo
# City 152 | washington
# City 153 | perdoes
# City 154 | akcaabat
# Record n/a
# Record n/a
# City 155 | okhotsk
# City 156 | tuatapere
# City 157 | puerto leguizamo
# City 158 | sitka
# City 159 | wasilla
# Record n/a
# City 160 | vardo
# City 161 | beidao
# City 162 | bowen
# City 163 | codrington
# Record n/a
# City 164 | araouane
# City 165 | cockburn town
# City 166 | san juan
# City 167 | kargasok
# City 168 | ambon
# City 169 | sortland
# City 170 | bealanana
# City 171 | buala
# City 172 | campbell river
# City 173 | dunedin
# City 174 | lixourion
# City 175 | bengkulu
# City 176 | novikovo
# City 177 | halifax
# City 178 | marawi
# City 179 | xuanwu
# City 180 | lebu
# City 181 | sept-iles
# City 182 | pizarro
# City 183 | lasa
# City 184 | sao felix do xingu
# City 185 | kushnarenkovo
# City 186 | new norfolk
# City 187 | gayny
# City 188 | te anau
# City 189 | kirkland lake
# City 190 | keskin
# City 191 | westport
# City 192 | ankang
# City 193 | aripuana
# Record n/a
# City 194 | vestmannaeyjar
# City 195 | walvis bay
# City 196 | abalak
# City 197 | poronaysk
# City 198 | katsuura
# City 199 | fairmont
# City 200 | henties bay
# City 201 | mantua
# City 202 | rundu
# City 203 | sioux lookout
# City 204 | pisco
# Record n/a
# City 205 | wewak
# City 206 | bam
# City 207 | anamur
# City 208 | faanui
# City 209 | guasdualito
# City 210 | ostrovnoy
# City 211 | rocha
# City 212 | srednekolymsk
# City 213 | vao
# City 214 | suntar
# City 215 | kloulklubed
# City 216 | wadi musa
# City 217 | saint george
# City 218 | shikarpur
# City 219 | broome
# Record n/a
# City 220 | necochea
# City 221 | tripoli
# City 222 | floirac
# City 223 | nishihara
# City 224 | kaitangata
# City 225 | avarua
# City 226 | deori khas
# Record n/a
# City 227 | kavieng
# City 228 | manono
# City 229 | adrar
# City 230 | longhua
# Record n/a
# Record n/a
# City 231 | bonoua
# City 232 | port macquarie
# City 233 | benalla
# Record n/a
# City 234 | roald
# City 235 | spring valley
# City 236 | fairbanks
# City 237 | matamoros
# City 238 | lubango
# City 239 | stokmarknes
# City 240 | malazgirt
# City 241 | talnakh
# City 242 | quang ngai
# City 243 | bathsheba
# City 244 | victoria
# City 245 | hoquiam
# City 246 | urumqi
# City 247 | khatanga
# City 248 | saint-pierre
# City 249 | nantucket
# City 250 | mehran
# City 251 | ribeira grande
# City 252 | makakilo city
# City 253 | geraldton
# City 254 | morgan city
# City 255 | ulladulla
# City 256 | mezhdurechensk
# Record n/a
# City 257 | lompoc
# City 258 | artesia
# City 259 | ayan
# Record n/a
# City 260 | tuktoyaktuk
# Record n/a
# City 261 | alekseyevsk
# City 262 | calama
# City 263 | uray
# City 264 | saint-francois
# City 265 | cabedelo
# City 266 | rio grande
# City 267 | darnah
# City 268 | taoudenni
# City 269 | monroe
# City 270 | sangolqui
# City 271 | pinawa
# City 272 | georgetown
# City 273 | deputatskiy
# City 274 | isangel
# City 275 | burgeo
# City 276 | blairmore
# City 277 | ucluelet
# City 278 | canturay
# City 279 | ilulissat
# City 280 | brae
# City 281 | zhezkazgan
# Record n/a
# City 282 | berlevag
# City 283 | pangnirtung
# City 284 | tecoanapa
# City 285 | porto velho
# City 286 | ponta do sol
# City 287 | semporna
# City 288 | beloha
# City 289 | hanna
# City 290 | iqaluit
# City 291 | ostra
# Record n/a
# Record n/a
# City 292 | kichera
# City 293 | maraa
# City 294 | roma
# Record n/a
# City 295 | shimoda
# Record n/a
# City 296 | hamilton
# City 297 | inuvik
# City 298 | bubaque
# Record n/a
# City 299 | gillette
# City 300 | emilio carranza
# City 301 | gilgit
# Record n/a
# City 302 | san patricio
# City 303 | raudeberg
# City 304 | kununurra
# City 305 | faya
# City 306 | mahajanga
# City 307 | cercal
# City 308 | port blair
# Record n/a
# City 309 | marzuq
# City 310 | acajutla
# City 311 | fuente palmera
# City 312 | kosonsoy
# City 313 | castro
# City 314 | napasar
# City 315 | grindavik
# City 316 | bolu
# City 317 | pedernales
# City 318 | ketovo
# City 319 | hellvik
# City 320 | kavaratti
# City 321 | stornoway
# City 322 | colares
# City 323 | gimbi
# City 324 | natal
# City 325 | lannion
# City 326 | ahipara
# City 327 | cabo san lucas
# City 328 | uige
# City 329 | baruun-urt
# City 330 | kodinsk
# City 331 | morondava
# City 332 | asau
# City 333 | severo-kurilsk
# City 334 | portland
# City 335 | salinopolis
# City 336 | teya
# City 337 | kutum
# City 338 | guerrero negro
# City 339 | huadian
# City 340 | omboue
# City 341 | nador
# Record n/a
# City 342 | nyrob
# City 343 | lagoa
# City 344 | mosquera
# City 345 | tukrah
# City 346 | thunder bay
# City 347 | bodden town
# City 348 | gerash
# City 349 | ray
# City 350 | lukovetskiy
# City 351 | inirida
# Record n/a
# City 352 | puerto baquerizo moreno
# City 353 | kulu
# City 354 | slobidka
# City 355 | gostyn
# City 356 | blythe
# City 357 | xining
# City 358 | constitucion
# City 359 | pevek
# City 360 | karratha
# City 361 | manzanillo
# City 362 | belaya gora
# City 363 | gisborne
# City 364 | ancud
# City 365 | aleksandrovskoye
# City 366 | biscarrosse
# City 367 | pocone
# City 368 | brokopondo
# City 369 | turochak
# City 370 | russell
# City 371 | chapais
# City 372 | inta
# City 373 | miramar
# City 374 | caravelas
# City 375 | trinidad
# City 376 | vagay
# City 377 | blagoveshchensk
# Record n/a
# City 378 | williams lake
# City 379 | griffith
# City 380 | nyurba
# City 381 | fallon
# City 382 | kourou
# City 383 | pak phanang
# City 384 | ahmadnagar
# City 385 | mizdah
# City 386 | pochutla
# City 387 | remanso
# City 388 | de aar
# City 389 | puerto escondido
# City 390 | vanimo
# City 391 | verkhnyaya inta
# Record n/a
# City 392 | sambava
# City 393 | livingstone
# Record n/a
# City 394 | asyut
# City 395 | songjianghe
# City 396 | george town
# City 397 | marienburg
# City 398 | kahuta
# City 399 | maniitsoq
# City 400 | domoni
# City 401 | klaksvik
# City 402 | nenjiang
# City 403 | pimentel
# City 404 | forio
# City 405 | charters towers
# City 406 | coahuayana
# Record n/a
# Record n/a
# City 407 | council bluffs
# City 408 | conceicao do araguaia
# City 409 | waingapu
# Record n/a
# Record n/a
# City 410 | praia da vitoria
# City 411 | maceio
# City 412 | hengyang
# City 413 | fortuna
# City 414 | nouakchott
# Record n/a
# City 415 | filadelfia
# Record n/a
# City 416 | kirakira
# Record n/a
# City 417 | gazli
# City 418 | kedrovyy
# City 419 | tongliao
# City 420 | ostersund
# City 421 | flinders
# Record n/a
# Record n/a
# Record n/a
# City 422 | togur
# City 423 | margate
# Record n/a
# City 424 | bolshaya sosnova
# City 425 | eganville
# City 426 | den helder
# Record n/a
# City 427 | boende
# City 428 | chumikan
# City 429 | ranong
# City 430 | quatre cocos
# City 431 | liverpool
# City 432 | swellendam
# City 433 | orkney
# City 434 | aksha
# City 435 | gilleleje
# City 436 | namanyere
# City 437 | dali
# City 438 | nijar
# City 439 | tairua
# City 440 | bintulu
# City 441 | valparaiso
# City 442 | shakawe
# City 443 | the pas
# City 444 | najran
# City 445 | klyuchi
# City 446 | cacu
# Record n/a
# City 447 | palauig
# City 448 | waddan
# City 449 | paamiut
# City 450 | alofi
# City 451 | khash
# City 452 | borsad
# City 453 | nioro
# City 454 | kaabong
# City 455 | japura
# City 456 | okha
# City 457 | ahuimanu
# City 458 | hoogstraten
# City 459 | san cristobal
# City 460 | ponta delgada
# City 461 | rambha
# Record n/a
# City 462 | christchurch
# City 463 | muttupet
# City 464 | half moon bay
# City 465 | rovenki
# City 466 | luoyang
# City 467 | namatanai
# City 468 | inhambane
# City 469 | tiksi
# City 470 | tres arroyos
# City 471 | muros
# City 472 | morant bay
# City 473 | piacabucu
# City 474 | polovinnoye
# City 475 | marsa matruh
# Record n/a
# City 476 | fare
# City 477 | yuncheng
# City 478 | diamantino
# City 479 | kisiwani
# City 480 | brockville
# City 481 | tra vinh
# City 482 | ajaccio
# City 483 | havoysund
# City 484 | lazaro cardenas
# City 485 | susanino
# City 486 | emerald
# City 487 | severodvinsk
# City 488 | alfter
# City 489 | voi
# Record n/a
# City 490 | kondoa
# City 491 | marinette
# City 492 | broken hill
# City 493 | olinda
# City 494 | jalingo
# City 495 | nuuk
# City 496 | nalut
# City 497 | tutoia
# City 498 | benguela
# City 499 | hanzhong
# City 500 | tabuk
# City 501 | upata
# City 502 | gamba
# City 503 | cumanayagua
# City 504 | great falls
# City 505 | palmer
# City 506 | port hedland
# City 507 | lhokseumawe
# City 508 | el dorado
# City 509 | pyinmana
# City 510 | whitehorse
# City 511 | jumla
# Record n/a
# City 512 | huancabamba
# Record n/a
# City 513 | kirensk
# City 514 | nizhnevartovsk
# City 515 | vizinga
# City 516 | bambanglipuro
# City 517 | lesnyye polyany
# City 518 | yumen
# City 519 | havre
# City 520 | churapcha
# City 521 | san-pedro
# City 522 | sapa
# City 523 | magistralnyy
# City 524 | pensilvania
# City 525 | iskateley
# City 526 | aliaga
# City 527 | liliani
# Record n/a
# Record n/a
# City 528 | mayo
# Record n/a
# Record n/a
# City 529 | marovoay
# City 530 | pangoa
# City 531 | pangai
# City 532 | mayna
# City 533 | yagodnoye
# City 534 | gunjur
# City 535 | provideniya
# City 536 | atar
# City 537 | esna
# City 538 | dryden
# City 539 | ramona
# City 540 | seoul
# City 541 | tura
# City 542 | pringsewu
# City 543 | sydney
# City 544 | lagos
# City 545 | nelson bay
# City 546 | panguna
# City 547 | lavrentiya
# City 548 | victor harbor
# City 549 | sorland
# City 550 | ullapool
# City 551 | hervey bay
# City 552 | ingleside
# City 553 | burnie
# City 554 | batticaloa
# City 555 | lata
# Record n/a
# Record n/a
# City 556 | banyo
# City 557 | bac lieu
# Complete!

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Per isntructions - For final notebook, save a csv of all retrieved data
weather_df.to_csv(r'output_data\weater_data.csv')
total_cities = len(weather_df)
total_cities
# Out:
# 557

# %%
# Display the data
# Create weather dictionary from attributes in loop. Use this dictionary to create a pandas data frame.
weather_dictionary = {
                     "City ID": city_id,
                     "City": city_name,
                     "Country": country,
                     "Latitude": lat,
                     "Longitude": lng,
                     "Date": date,
                     "Max. Temperature (F)": max_temp,
                     "Cloudiness (%)": cloudiness,
                     "Humidity (%)": humidity,
                     "Wind Speed (mph)": wind_speed}

# Data Frame
weather_df = pd.DataFrame(weather_dictionary)
weather_df.head()
# Out:
#    City ID      City Country  Latitude  Longitude        Date  \
# 0  2206939     Bluff      NZ  -46.6000   168.3333  1592697600
# 1  2419992    Kankan      GN   10.3854    -9.3057  1592697600
# 2  3414079  Olafsvik      IS   64.8945   -23.7142  1592697600
# 3  1265996  Kothāpet      IN   19.3333    79.4833  1592697600
# 4  4030556   Rikitea      PF  -23.1203  -134.9692  1592697600
#
#    Max. Temperature (F)  Cloudiness (%)  Humidity (%)  Wind Speed (mph)
# 0                 44.11              15            79              7.76
# 1                 76.86              36            78              4.81
# 2                 51.17              72            87              2.37
# 3                 82.63             100            70              4.36
# 4                 76.06              62            83             11.81

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.sort_values("Humidity (%)", ascending=False)
# Out:
#      City ID           City Country  Latitude  Longitude        Date  \
# 322   336496          Gimbi      ET    9.1667    35.8333  1592697600
# 258  2027316           Ayan      RU   56.4500   138.1667  1592697600
# 490  5261852      Marinette      US   45.1000   -87.6307  1592697600
# 116  1795632     Shenjiamen      CN   29.9576   122.2980  1592697600
# 350  3671450        Inírida      CO    3.8653   -67.9239  1592697600
# ..       ...            ...     ...       ...        ...         ...
# 380  5503914         Fallon      US   39.4735  -118.7774  1592697600
# 267  2450173      Taoudenni      ML   22.6783    -3.9836  1592697600
# 355  5329649         Blythe      US   33.6103  -114.5964  1592697600
# 216  5546220   Saint George      US   37.1041  -113.5841  1592697600
# 234  5512909  Spring Valley      US   36.1080  -115.2450  1592697600
#
#      Max. Temperature (F)  Cloudiness (%)  Humidity (%)  Wind Speed (mph)
# 322                 57.20              92           100              3.11
# 258                 42.10             100            98              6.73
# 490                 63.61              95            98              5.28
# 116                 71.13             100            97             17.00
# 350                 75.34             100            97              1.92
# ..                    ...             ...           ...               ...
# 380                 94.03              81            11             10.38
# 267                103.51              32             8              9.19
# 355                106.32               1             8             10.29
# 216                 98.47              17             8              9.57
# 234                101.55              32             8              2.01
#
# [557 rows x 10 columns]

# %%
# AFTER SORTING BY DESCENDING HUMIDITY, THERE ARE NO VALUES THAT SHOW HUMIDITY OVER 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create scatter plot to showcase Temperature (F) vs. Latitude
plot_lat = weather_df['Latitude']
plot_temp = weather_df['Max. Temperature (F)']

plt.figure(figsize=(7,7))
plt.scatter(plot_lat, plot_temp)
plt.title('City Latitude vs. Max. Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)
plt.savefig('temp_vs_lat_scatter')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create scatter plot to showcase Humidity (%) vs. Latitude
plot_lat = weather_df['Latitude']
plot_hum = weather_df['Humidity (%)']

plt.figure(figsize=(7,7))
plt.scatter(plot_lat, plot_hum)
plt.title('City Latitude vs. Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig('hum_vs_lat_scatter')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create scatter plot to showcase Cloudiness (%) vs. Latitude
plot_lat = weather_df['Latitude']
plot_cloud = weather_df['Cloudiness (%)']

plt.figure(figsize=(7,7))
plt.scatter(plot_lat, plot_cloud)
plt.title('City Latitude vs. Cloudiness (%)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('cloud_vs_lat_scatter')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create scatter plot to showcase Wind Speed (mph) vs. Latitude
plot_lat = weather_df['Latitude']
plot_wind = weather_df['Wind Speed (mph)']

plt.figure(figsize=(7,7))
plt.scatter(plot_lat, plot_hum)
plt.title('City Latitude vs. Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('wind_vs_lat_scatter')
plt.show()

# %%
# Can't determine why wind scatter is showing much higher values than are shown in the dataframe...
weather_df.sort_values("Wind Speed (mph)", ascending=False)
# Out:
#      City ID         City Country  Latitude  Longitude        Date  \
# 126    64814  Bandarbeyla      SO    9.4942    50.8122  1592697600
# 70   1507390       Dikson      RU   73.5069    80.5464  1592697600
# 448  3421193      Paamiut      GL   61.9940   -49.6678  1592697600
# 62     57000        Hobyo      SO    5.3505    48.5268  1592697600
# 449  4036284        Alofi      NU  -19.0595  -169.9187  1592697600
# ..       ...          ...     ...       ...        ...         ...
# 498  1808857     Hanzhong      CN   33.0728   107.0303  1592697600
# 545  2088659      Panguna      PG   -6.3164   155.4848  1592697600
# 39    110690         Abhā      SA   18.2164    42.5053  1592697600
# 465  1801792      Luoyang      CN   34.6836   112.4536  1592697600
# 239   304916    Malazgirt      TR   39.1427    42.5401  1592697600
#
#      Max. Temperature (F)  Cloudiness (%)  Humidity (%)  Wind Speed (mph)
# 126                 79.74              98            72             27.40
# 70                  35.98              99            84             25.12
# 448                 40.10              85            83             24.83
# 62                  79.70               7            67             24.74
# 449                 76.82             100            82             24.16
# ..                    ...             ...           ...               ...
# 498                 69.01              93            83              0.63
# 545                 82.76              70            80              0.58
# 39                  70.72              97            43              0.47
# 465                 76.15               3            31              0.45
# 239                 51.40              16            66              0.34
#
# [557 rows x 10 columns]

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def lin_reg_plot(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
# Run linear regression on each relationship, separating them into... 
# ...Northern Hemisphere (greater than or equal to 0 degrees latitude) and...
# ...Southern Hemisphere (less than 0 degrees latitude)

# %%
# Create Northern Hemisphere DF
north_df = weather_df.loc[weather_df['Latitude'] >= 0,:]
north_df.head()
# Out:
#    City ID       City Country  Latitude  Longitude        Date  \
# 1  2419992     Kankan      GN   10.3854    -9.3057  1592697600
# 2  3414079   Olafsvik      IS   64.8945   -23.7142  1592697600
# 3  1265996   Kothāpet      IN   19.3333    79.4833  1592697600
# 8  5882953    Aklavik      CA   68.2191  -135.0107  1592697600
# 9  3418910  Upernavik      GL   72.7868   -56.1549  1592697600
#
#    Max. Temperature (F)  Cloudiness (%)  Humidity (%)  Wind Speed (mph)
# 1                 76.86              36            78              4.81
# 2                 51.17              72            87              2.37
# 3                 82.63             100            70              4.36
# 8                 46.78              95            82             15.12
# 9                 40.77               0            72              9.55

# %%
# Create Southern Hemisphere DF
south_df = weather_df.loc[weather_df['Latitude'] < 0,:]
south_df.head()
# Out:
#    City ID          City Country  Latitude  Longitude        Date  \
# 0  2206939         Bluff      NZ  -46.6000   168.3333  1592697600
# 4  4030556       Rikitea      PF  -23.1203  -134.9692  1592697600
# 5  4020109        Atuona      PF   -9.8000  -139.0333  1592697600
# 6  3466165      Cidreira      BR  -30.1811   -50.2056  1592697600
# 7  3874787  Punta Arenas      CL  -53.1500   -70.9167  1592697600
#
#    Max. Temperature (F)  Cloudiness (%)  Humidity (%)  Wind Speed (mph)
# 0                 44.11              15            79              7.76
# 4                 76.06              62            83             11.81
# 5                 79.95               4            73             11.90
# 6                 67.23              39            91              9.26
# 7                 37.38              80            83              7.07

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Run linear regression on Northern Hemisphere - Max Temp vs. Latitude
north_df_lat = north_df['Latitude'].values.reshape(-1, 1)  # values converts it into a numpy array
north_df_temp = north_df['Max. Temperature (F)'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(north_df_lat, north_df_temp)  # perform linear regression
north_df_temp_pred = linear_regressor.predict(north_df_lat)  # make predictions

plt.figure(figsize=(7,7))
plt.scatter(north_df_lat, north_df_temp)
plt.plot(north_df_lat, north_df_temp_pred, color='red')
plt.xlabel("Latitude")
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.savefig('north_temp_lat_lr')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Run linear regression on Southern Hemisphere - Max Temp vs. Latitude
south_df_lat = south_df['Latitude'].values.reshape(-1, 1)  # values converts it into a numpy array
south_df_temp = south_df['Max. Temperature (F)'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(south_df_lat, south_df_temp)  # perform linear regression
south_df_temp_pred = linear_regressor.predict(south_df_lat)  # make predictions

plt.figure(figsize=(7,7))
plt.scatter(south_df_lat, south_df_temp)
plt.plot(south_df_lat, south_df_temp_pred, color='red')
plt.xlabel("Latitude")
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.savefig('south_temp_lat_lr')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Run linear regression on Northern Hemisphere - Humidity (%) vs. Latitude
north_df_lat = north_df['Latitude'].values.reshape(-1, 1)  # values converts it into a numpy array
north_df_hum = north_df['Humidity (%)'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(north_df_lat, north_df_hum)  # perform linear regression
north_df_hum_pred = linear_regressor.predict(north_df_lat)  # make predictions

plt.figure(figsize=(7,7))
plt.scatter(north_df_lat, north_df_hum)
plt.plot(north_df_lat, north_df_hum_pred, color='red')
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')
plt.savefig('north_hum_lat_lr')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Run linear regression on Southern Hemisphere - Humidity (%) vs. Latitude
south_df_lat = south_df['Latitude'].values.reshape(-1, 1)  # values converts it into a numpy array
south_df_hum = south_df['Humidity (%)'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(south_df_lat, south_df_hum)  # perform linear regression
south_df_hum_pred = linear_regressor.predict(south_df_lat)  # make predictions

plt.figure(figsize=(7,7))
plt.scatter(south_df_lat, south_df_hum)
plt.plot(south_df_lat, south_df_hum_pred, color='red')
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')
plt.savefig('south_hum_lat_lr')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Run linear regression on Northern Hemisphere - Cloudiness (%) vs. Latitude
north_df_lat = north_df['Latitude'].values.reshape(-1, 1)  # values converts it into a numpy array
north_df_cloud = north_df['Cloudiness (%)'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(north_df_lat, north_df_cloud)  # perform linear regression
north_df_cloud_pred = linear_regressor.predict(north_df_lat)  # make predictions

plt.figure(figsize=(7,7))
plt.scatter(north_df_lat, north_df_cloud)
plt.plot(north_df_lat, north_df_cloud_pred, color='red')
plt.xlabel("Latitude")
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')
plt.savefig('north_cloud_lat_lr')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Run linear regression on Southern Hemisphere - Cloudiness (%) vs. Latitude
south_df_lat = south_df['Latitude'].values.reshape(-1, 1)  # values converts it into a numpy array
south_df_cloud = south_df['Cloudiness (%)'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(south_df_lat, south_df_cloud)  # perform linear regression
south_df_cloud_pred = linear_regressor.predict(south_df_lat)  # make predictions

plt.figure(figsize=(7,7))
plt.scatter(south_df_lat, south_df_cloud)
plt.plot(south_df_lat, south_df_cloud_pred, color='red')
plt.xlabel("Latitude")
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')
plt.savefig('south_cloud_lat_lr')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Run linear regression on Northern Hemisphere - Wind Speed (mph) vs. Latitude
north_df_lat = north_df['Latitude'].values.reshape(-1, 1)  # values converts it into a numpy array
north_df_wind = north_df['Wind Speed (mph)'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(north_df_lat, north_df_wind)  # perform linear regression
north_df_wind_pred = linear_regressor.predict(north_df_lat)  # make predictions

plt.figure(figsize=(7,7))
plt.scatter(north_df_lat, north_df_wind)
plt.plot(north_df_lat, north_df_wind_pred, color='red')
plt.xlabel("Latitude")
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')
plt.savefig('north_wind_lat_lr')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Run linear regression on Southern Hemisphere - Wind Speed (mph) vs. Latitude
south_df_lat = south_df['Latitude'].values.reshape(-1, 1)  # values converts it into a numpy array
south_df_wind = south_df['Wind Speed (mph)'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(south_df_lat, south_df_wind)  # perform linear regression
south_df_wind_pred = linear_regressor.predict(south_df_lat)  # make predictions

plt.figure(figsize=(7,7))
plt.scatter(south_df_lat, south_df_wind)
plt.plot(south_df_lat, south_df_wind_pred, color='red')
plt.xlabel("Latitude")
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')
plt.savefig('south_wind_lat_lr')
plt.show()

# %%
print("statement about linear regressions")
# Out:
# statement about linear regressions
