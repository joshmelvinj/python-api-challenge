# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#API CALL URL = http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID={YOUR API KEY}
base_url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
weather_api_key = "1c8babe22822ec7715d3f85b5b6dcd85"
url = base_url + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=1c8babe22822ec7715d3f85b5b6dcd85'

# %%
# Make call
response = requests.get(url)
weather_json = response.json()
weather_json
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1592946000,
#    'main': {'temp': 291.67,
#     'feels_like': 292.51,
#     'temp_min': 291.26,
#     'temp_max': 291.67,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1002,
#     'humidity': 75,
#     'temp_kf': 0.41},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 19},
#    'wind': {'speed': 0.61, 'deg': 32},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-23 21:00:00'},
#   {'dt': 1592956800,
#    'main': {'temp': 290.37,
#     'feels_like': 289.24,
#     'temp_min': 289.91,
#     'temp_max': 290.37,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1003,
#     'humidity': 69,
#     'temp_kf': 0.46},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.28, 'deg': 347},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-24 00:00:00'},
#   {'dt': 1592967600,
#    'main': {'temp': 290.74,
#     'feels_like': 288.56,
#     'temp_min': 290.65,
#     'temp_max': 290.74,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1003,
#     'humidity': 61,
#     'temp_kf': 0.09},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 3.17, 'deg': 332},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 03:00:00'},
#   {'dt': 1592978400,
#    'main': {'temp': 295.13,
#     'feels_like': 292.77,
#     'temp_min': 295.13,
#     'temp_max': 295.15,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1004,
#     'humidity': 47,
#     'temp_kf': -0.02},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.49, 'deg': 0},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 06:00:00'},
#   {'dt': 1592989200,
#    'main': {'temp': 298.45,
#     'feels_like': 294.9,
#     'temp_min': 298.45,
#     'temp_max': 298.45,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1005,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.27, 'deg': 0},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 09:00:00'},
#   {'dt': 1593000000,
#    'main': {'temp': 298.66,
#     'feels_like': 293.45,
#     'temp_min': 298.66,
#     'temp_max': 298.66,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1006,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 6.49, 'deg': 6},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 12:00:00'},
#   {'dt': 1593010800,
#    'main': {'temp': 295.87,
#     'feels_like': 289.63,
#     'temp_min': 295.87,
#     'temp_max': 295.87,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1006,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 6.58, 'deg': 9},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 15:00:00'},
#   {'dt': 1593021600,
#    'main': {'temp': 291.68,
#     'feels_like': 286.42,
#     'temp_min': 291.68,
#     'temp_max': 291.68,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1008,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.21, 'deg': 25},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-24 18:00:00'},
#   {'dt': 1593032400,
#    'main': {'temp': 289.15,
#     'feels_like': 284.74,
#     'temp_min': 289.15,
#     'temp_max': 289.15,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1009,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 4, 'deg': 38},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-24 21:00:00'},
#   {'dt': 1593043200,
#    'main': {'temp': 287.47,
#     'feels_like': 284.44,
#     'temp_min': 287.47,
#     'temp_max': 287.47,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1010,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 2.22, 'deg': 41},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-25 00:00:00'},
#   {'dt': 1593054000,
#    'main': {'temp': 287.91,
#     'feels_like': 285.6,
#     'temp_min': 287.91,
#     'temp_max': 287.91,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1011,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 1.22, 'deg': 7},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 03:00:00'},
#   {'dt': 1593064800,
#    'main': {'temp': 292.54,
#     'feels_like': 289.64,
#     'temp_min': 292.54,
#     'temp_max': 292.54,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1011,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 1.61, 'deg': 304},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 06:00:00'},
#   {'dt': 1593075600,
#    'main': {'temp': 296.85,
#     'feels_like': 293.56,
#     'temp_min': 296.85,
#     'temp_max': 296.85,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1010,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 2.7, 'deg': 291},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 09:00:00'},
#   {'dt': 1593086400,
#    'main': {'temp': 297.73,
#     'feels_like': 294.64,
#     'temp_min': 297.73,
#     'temp_max': 297.73,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1009,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 4.94, 'deg': 302},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 12:00:00'},
#   {'dt': 1593097200,
#    'main': {'temp': 294.12,
#     'feels_like': 292.93,
#     'temp_min': 294.12,
#     'temp_max': 294.12,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1008,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 71},
#    'wind': {'speed': 3.81, 'deg': 329},
#    'rain': {'3h': 5.76},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 15:00:00'},
#   {'dt': 1593108000,
#    'main': {'temp': 292.62,
#     'feels_like': 291.04,
#     'temp_min': 292.62,
#     'temp_max': 292.62,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1008,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 57},
#    'wind': {'speed': 3.88, 'deg': 16},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-25 18:00:00'},
#   {'dt': 1593118800,
#    'main': {'temp': 289.51,
#     'feels_like': 288.18,
#     'temp_min': 289.51,
#     'temp_max': 289.51,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1009,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.4, 'deg': 47},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-25 21:00:00'},
#   {'dt': 1593129600,
#    'main': {'temp': 288.48,
#     'feels_like': 287.96,
#     'temp_min': 288.48,
#     'temp_max': 288.48,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1011,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.18, 'deg': 15},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-26 00:00:00'},
#   {'dt': 1593140400,
#    'main': {'temp': 289.31,
#     'feels_like': 288.66,
#     'temp_min': 289.31,
#     'temp_max': 289.31,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1010,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.43, 'deg': 339},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-26 03:00:00'},
#   {'dt': 1593151200,
#    'main': {'temp': 293.66,
#     'feels_like': 292.19,
#     'temp_min': 293.66,
#     'temp_max': 293.66,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1011,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.94, 'deg': 339},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-26 06:00:00'},
#   {'dt': 1593162000,
#    'main': {'temp': 297.74,
#     'feels_like': 295.78,
#     'temp_min': 297.74,
#     'temp_max': 297.74,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1010,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.19, 'deg': 326},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-26 09:00:00'},
#   {'dt': 1593172800,
#    'main': {'temp': 299.51,
#     'feels_like': 297.44,
#     'temp_min': 299.51,
#     'temp_max': 299.51,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1008,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 31},
#    'wind': {'speed': 4.02, 'deg': 331},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-26 12:00:00'},
#   {'dt': 1593183600,
#    'main': {'temp': 299.86,
#     'feels_like': 297.75,
#     'temp_min': 299.86,
#     'temp_max': 299.86,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1007,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 28},
#    'wind': {'speed': 4.39, 'deg': 319},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-26 15:00:00'},
#   {'dt': 1593194400,
#    'main': {'temp': 296.91,
#     'feels_like': 295.61,
#     'temp_min': 296.91,
#     'temp_max': 296.91,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1006,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 3.74, 'deg': 285},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-26 18:00:00'},
#   {'dt': 1593205200,
#    'main': {'temp': 294.9,
#     'feels_like': 293.64,
#     'temp_min': 294.9,
#     'temp_max': 294.9,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1005,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.05, 'deg': 294},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-26 21:00:00'},
#   {'dt': 1593216000,
#    'main': {'temp': 293.6,
#     'feels_like': 291.84,
#     'temp_min': 293.6,
#     'temp_max': 293.6,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1005,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.92, 'deg': 299},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-27 00:00:00'},
#   {'dt': 1593226800,
#    'main': {'temp': 293.8,
#     'feels_like': 292.07,
#     'temp_min': 293.8,
#     'temp_max': 293.8,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1005,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 3.74, 'deg': 308},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-27 03:00:00'},
#   {'dt': 1593237600,
#    'main': {'temp': 298.38,
#     'feels_like': 296.2,
#     'temp_min': 298.38,
#     'temp_max': 298.38,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1004,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 22},
#    'wind': {'speed': 4.35, 'deg': 302},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-27 06:00:00'},
#   {'dt': 1593248400,
#    'main': {'temp': 300.82,
#     'feels_like': 297.47,
#     'temp_min': 300.82,
#     'temp_max': 300.82,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1003,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 23},
#    'wind': {'speed': 6.04, 'deg': 309},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-27 09:00:00'},
#   {'dt': 1593259200,
#    'main': {'temp': 301.92,
#     'feels_like': 298.72,
#     'temp_min': 301.92,
#     'temp_max': 301.92,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1002,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 5.73, 'deg': 312},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-27 12:00:00'},
#   {'dt': 1593270000,
#    'main': {'temp': 300.8,
#     'feels_like': 297.81,
#     'temp_min': 300.8,
#     'temp_max': 300.8,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1000,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 42},
#    'wind': {'speed': 5.86, 'deg': 295},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-27 15:00:00'},
#   {'dt': 1593280800,
#    'main': {'temp': 297.81,
#     'feels_like': 295.9,
#     'temp_min': 297.81,
#     'temp_max': 297.81,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1000,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 4.75, 'deg': 293},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-27 18:00:00'},
#   {'dt': 1593291600,
#    'main': {'temp': 295.96,
#     'feels_like': 294.31,
#     'temp_min': 295.96,
#     'temp_max': 295.96,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1000,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 4.34, 'deg': 297},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-27 21:00:00'},
#   {'dt': 1593302400,
#    'main': {'temp': 294.17,
#     'feels_like': 292.56,
#     'temp_min': 294.17,
#     'temp_max': 294.17,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 999,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 4.2, 'deg': 294},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-06-28 00:00:00'},
#   {'dt': 1593313200,
#    'main': {'temp': 294.05,
#     'feels_like': 292.59,
#     'temp_min': 294.05,
#     'temp_max': 294.05,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 998,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.16, 'deg': 287},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-28 03:00:00'},
#   {'dt': 1593324000,
#    'main': {'temp': 297.92,
#     'feels_like': 295.91,
#     'temp_min': 297.92,
#     'temp_max': 297.92,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 998,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 27},
#    'wind': {'speed': 4.94, 'deg': 308},
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-28 06:00:00'},
#   {'dt': 1593334800,
#    'main': {'temp': 300.15,
#     'feels_like': 297.5,
#     'temp_min': 300.15,
#     'temp_max': 300.15,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 997,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 5.28, 'deg': 321},
#    'rain': {'3h': 0.5},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-28 09:00:00'},
#   {'dt': 1593345600,
#    'main': {'temp': 300.75,
#     'feels_like': 298.64,
#     'temp_min': 300.75,
#     'temp_max': 300.75,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 996,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.42, 'deg': 306},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-28 12:00:00'},
#   {'dt': 1593356400,
#    'main': {'temp': 299.7,
#     'feels_like': 298.29,
#     'temp_min': 299.7,
#     'temp_max': 299.7,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 995,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.8, 'deg': 303},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-28 15:00:00'},
#   {'dt': 1593367200,
#    'main': {'temp': 297.25,
#     'feels_like': 297.07,
#     'temp_min': 297.25,
#     'temp_max': 297.25,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 994,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.44, 'deg': 308},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-06-28 18:00:00'}],
#  'city': {'id': 524901,
#   'name': 'Moscow',
#   'coord': {'lat': 55.7522, 'lon': 37.6156},
#   'country': 'RU',
#   'timezone': 10800,
#   'sunrise': 1592873112,
#   'sunset': 1592936297}}

# %%
# print(json.dumps(weather_json, indent=4, sort_keys=True))
# print location
json.dumps(weather_json, indent=4, sort_keys=True)
print(weather_json["city"]['name'])
# Out:
# Moscow

# %%
# Per isntructions - For final notebook, perform a weather check on each of... 
# ...the cities using a series of successive API calls
# Create empty lists to hold response information
city_id = []
city_name = []
cloudiness = []
country = []
lat = []
lng = []
date = []
max_temp = []
humidity = []
wind_speed = []
count = 0

# Loop through city list and request data from each city for the variables above, print N/A for those not found
for city in cities:
    response = requests.get(url + "&q=" + city + "&units=Imperial")
    weather_json = response.json()
    try:
        city_id.append(weather_json['city']['id'])
        city_name.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        date.append(weather_json['list'][0]['dt'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"City {count} | {city}")
    except:
        print("Record n/a") 
        pass
        
print("Complete!")
# Out:
# City 1 | mahebourg
# City 2 | hermanus
# City 3 | plettenberg bay
# Record n/a
# City 4 | xuddur
# City 5 | jamestown
# City 6 | mahon
# City 7 | cidreira
# City 8 | wewak
# City 9 | qui nhon
# City 10 | puerto ayora
# City 11 | viiratsi
# City 12 | bluff
# City 13 | norman wells
# City 14 | jacareacanga
# City 15 | busselton
# City 16 | qaanaaq
# City 17 | nikolskoye
# City 18 | cabo san lucas
# City 19 | hilo
# City 20 | saint-philippe
# City 21 | albany
# City 22 | butaritari
# City 23 | vilyuysk
# City 24 | lasa
# City 25 | westport
# City 26 | faanui
# Record n/a
# City 27 | natal
# City 28 | ushuaia
# City 29 | kangaatsiaq
# City 30 | vaini
# City 31 | nanortalik
# City 32 | tshikapa
# City 33 | verkhnyaya toyma
# City 34 | soyo
# City 35 | avarua
# City 36 | mataura
# City 37 | punta arenas
# City 38 | hobart
# City 39 | saint george
# City 40 | kaitangata
# City 41 | bathsheba
# City 42 | boyolangu
# City 43 | manokwari
# City 44 | tasiilaq
# City 45 | georgetown
# City 46 | clonakilty
# City 47 | golden
# City 48 | pevek
# City 49 | atuona
# City 50 | savannah bight
# Record n/a
# City 51 | tuktoyaktuk
# City 52 | vao
# City 53 | baisha
# City 54 | humberto de campos
# City 55 | arraial do cabo
# City 56 | mounana
# Record n/a
# City 57 | namibe
# City 58 | severo-kurilsk
# City 59 | san carlos
# City 60 | olinda
# City 61 | eureka
# City 62 | clarence town
# City 63 | curup
# City 64 | fallon
# City 65 | barmer
# City 66 | alta floresta
# City 67 | aki
# Record n/a
# City 68 | rikitea
# City 69 | oksfjord
# Record n/a
# City 70 | muyezerskiy
# City 71 | srednekolymsk
# City 72 | ipira
# City 73 | hithadhoo
# City 74 | verkhnyaya inta
# City 75 | yellowknife
# City 76 | te anau
# City 77 | port alfred
# City 78 | ust-tsilma
# City 79 | ostrovnoy
# City 80 | tateyama
# City 81 | esperance
# City 82 | saskylakh
# City 83 | bogorodskoye
# City 84 | longyearbyen
# City 85 | darlington
# City 86 | krasnyy luch
# City 87 | shawnee
# City 88 | port elizabeth
# City 89 | barrow
# Record n/a
# Record n/a
# City 90 | namatanai
# City 91 | tiksi
# City 92 | hovd
# City 93 | kapaa
# City 94 | hetauda
# City 95 | dikson
# City 96 | hohhot
# City 97 | bucak
# City 98 | saint-joseph
# City 99 | atar
# City 100 | mecca
# City 101 | new norfolk
# City 102 | chokurdakh
# City 103 | chuy
# Record n/a
# City 104 | iztapa
# City 105 | klaksvik
# City 106 | sarangarh
# Record n/a
# City 107 | helena
# City 108 | atasu
# City 109 | baykit
# City 110 | bredasdorp
# Record n/a
# City 111 | grand-santi
# City 112 | kampene
# City 113 | bilma
# City 114 | laguna
# City 115 | kargasok
# City 116 | bemidji
# City 117 | bengkulu
# City 118 | poronaysk
# City 119 | ribeira grande
# City 120 | mar del plata
# City 121 | adrar
# City 122 | cherskiy
# City 123 | muisne
# City 124 | husavik
# City 125 | kodiak
# City 126 | nome
# City 127 | tepanguare
# City 128 | morros
# City 129 | khatanga
# City 130 | la ronge
# City 131 | milkovo
# Record n/a
# City 132 | natitingou
# City 133 | castro
# City 134 | mehamn
# City 135 | ahipara
# City 136 | lebu
# City 137 | clyde river
# City 138 | jiangyou
# Record n/a
# City 139 | henties bay
# City 140 | san policarpo
# City 141 | ilulissat
# City 142 | ust-omchug
# City 143 | la sarre
# Record n/a
# City 144 | airai
# City 145 | quatre cocos
# Record n/a
# City 146 | brooks
# City 147 | yerbogachen
# City 148 | portland
# City 149 | iqaluit
# City 150 | martapura
# City 151 | muzaffarabad
# City 152 | sijunjung
# City 153 | hashtrud
# City 154 | cape canaveral
# City 155 | mehran
# City 156 | pacifica
# City 157 | kavaratti
# City 158 | ambilobe
# City 159 | mareeba
# City 160 | luangwa
# City 161 | bambous virieux
# Record n/a
# City 162 | wasserburg
# City 163 | omboue
# City 164 | verkhoyansk
# Record n/a
# City 165 | cape town
# City 166 | luderitz
# City 167 | richards bay
# City 168 | kashi
# City 169 | khorixas
# City 170 | bethel
# City 171 | vardo
# City 172 | rajbiraj
# City 173 | krasnoarmeysk
# City 174 | thompson
# City 175 | moscow
# City 176 | torit
# Record n/a
# City 177 | nuuk
# City 178 | riyadh
# City 179 | obzor
# City 180 | okakarara
# Record n/a
# City 181 | shingu
# City 182 | labuhan
# City 183 | geraldton
# City 184 | tuatapere
# City 185 | polyarnyy
# City 186 | gweta
# City 187 | jian
# City 188 | yumen
# City 189 | mayumba
# City 190 | hede
# City 191 | pangody
# City 192 | vega de alatorre
# City 193 | rio grande
# City 194 | inta
# City 195 | santa marta
# City 196 | kungurtug
# City 197 | banda aceh
# City 198 | amapa
# City 199 | banjar
# City 200 | genoa
# Record n/a
# Record n/a
# City 201 | half moon bay
# City 202 | kurtalan
# City 203 | north bend
# City 204 | los alamos
# Record n/a
# City 205 | santiago del estero
# City 206 | cuauhtemoc
# City 207 | brownsville
# City 208 | grindavik
# City 209 | kavieng
# City 210 | itarema
# City 211 | veinticinco de mayo
# City 212 | rensvik
# City 213 | monywa
# City 214 | souillac
# City 215 | codrington
# City 216 | huarmey
# City 217 | makakilo city
# City 218 | bubaque
# City 219 | loucna nad desnou
# Record n/a
# City 220 | northam
# City 221 | maarianhamina
# City 222 | carnarvon
# Record n/a
# City 223 | jijiga
# City 224 | aykhal
# City 225 | sibu
# City 226 | avera
# City 227 | college
# City 228 | antofagasta
# City 229 | moree
# City 230 | catamarca
# City 231 | zambezi
# City 232 | meulaboh
# City 233 | turukhansk
# City 234 | trelew
# City 235 | chibuto
# City 236 | san nicolas
# City 237 | villaba
# City 238 | hare bay
# City 239 | east london
# City 240 | praia da vitoria
# City 241 | kysyl-syr
# City 242 | hasaki
# City 243 | rampur hat
# City 244 | vila velha
# Record n/a
# City 245 | egvekinot
# Record n/a
# City 246 | emba
# Record n/a
# City 247 | aklavik
# Record n/a
# City 248 | viedma
# City 249 | charters towers
# City 250 | tarbes
# City 251 | mackay
# City 252 | coracora
# City 253 | yafran
# City 254 | tigil
# City 255 | victoria
# City 256 | margate
# City 257 | barao de melgaco
# City 258 | sinjar
# City 259 | licheng
# City 260 | buckeye
# City 261 | pacific grove
# City 262 | touros
# City 263 | tautira
# Record n/a
# City 264 | marsh harbour
# City 265 | inhambane
# City 266 | ancud
# City 267 | beidao
# City 268 | skibbereen
# City 269 | broome
# City 270 | buraydah
# City 271 | kabelvag
# City 272 | oyo
# City 273 | labuan
# City 274 | longyan
# City 275 | zhigansk
# City 276 | nortelandia
# City 277 | rawson
# City 278 | yaan
# City 279 | hofn
# City 280 | nantucket
# City 281 | san jeronimo
# City 282 | nehe
# City 283 | saint-augustin
# City 284 | san jose del guaviare
# City 285 | marawi
# City 286 | kaeo
# City 287 | yatou
# City 288 | fort wellington
# City 289 | pedernales
# City 290 | antsohihy
# City 291 | yar-sale
# City 292 | coihaique
# City 293 | kalmunai
# City 294 | rivne
# City 295 | seoul
# City 296 | inuvik
# City 297 | soma
# City 298 | hastings
# City 299 | gimli
# City 300 | gizo
# City 301 | palana
# City 302 | maragogi
# City 303 | bukachacha
# City 304 | petukhovo
# City 305 | lubango
# City 306 | kunyang
# City 307 | puerto escondido
# City 308 | bull savanna
# City 309 | port blair
# City 310 | letlhakeng
# City 311 | pangnirtung
# City 312 | tagusao
# City 313 | mount gambier
# City 314 | sao filipe
# City 315 | port lincoln
# City 316 | oga
# Record n/a
# City 317 | ulaanbaatar
# City 318 | ayan
# City 319 | dondo
# City 320 | provideniya
# City 321 | pala
# City 322 | mount isa
# City 323 | tempio pausania
# Record n/a
# City 324 | duiwelskloof
# City 325 | eregli
# City 326 | maroantsetra
# City 327 | bonthe
# City 328 | valparaiso
# City 329 | beringovskiy
# City 330 | marrakesh
# City 331 | brae
# City 332 | mitu
# City 333 | leh
# City 334 | samarai
# City 335 | port-cartier
# City 336 | parnamirim
# City 337 | meiganga
# City 338 | necochea
# City 339 | buncrana
# City 340 | dwarka
# City 341 | guarapari
# City 342 | upernavik
# City 343 | andenes
# City 344 | tilichiki
# City 345 | padang
# City 346 | najran
# City 347 | naryan-mar
# City 348 | bilibino
# City 349 | tazovskiy
# City 350 | houma
# City 351 | saint-francois
# City 352 | merrill
# City 353 | cayenne
# City 354 | freeport
# City 355 | leningradskiy
# City 356 | mednogorsk
# City 357 | moerai
# City 358 | makurdi
# City 359 | palauig
# City 360 | velez-malaga
# City 361 | penhold
# City 362 | linqiong
# City 363 | kahului
# City 364 | qadirpur ran
# City 365 | odesskoye
# City 366 | vila franca do campo
# City 367 | talnakh
# City 368 | guanare
# City 369 | tselinnoye
# City 370 | camapua
# City 371 | yerofey pavlovich
# City 372 | chute-aux-outardes
# City 373 | isangel
# City 374 | lagoa
# City 375 | filadelfia
# City 376 | narsaq
# City 377 | lesosibirsk
# City 378 | hamilton
# City 379 | ponta do sol
# City 380 | guerrero negro
# City 381 | barra patuca
# City 382 | junin
# City 383 | sidney
# City 384 | broken hill
# City 385 | ferme-neuve
# Record n/a
# City 386 | cabra
# City 387 | dunedin
# City 388 | torbay
# City 389 | aksu
# City 390 | mogok
# City 391 | bari
# City 392 | champerico
# City 393 | ixtapa
# City 394 | lukovetskiy
# City 395 | adra
# City 396 | idenao
# City 397 | lata
# City 398 | mitsamiouli
# City 399 | hay river
# City 400 | kupang
# City 401 | yenagoa
# City 402 | lompoc
# City 403 | kutum
# City 404 | marystown
# City 405 | vestmannaeyjar
# City 406 | kloulklubed
# City 407 | alappuzha
# City 408 | markova
# City 409 | ahuimanu
# City 410 | cocorit
# City 411 | changli
# City 412 | pahrump
# Record n/a
# City 413 | monaghan
# City 414 | alofi
# City 415 | tual
# City 416 | wadi maliz
# Record n/a
# City 417 | macas
# City 418 | uarini
# City 419 | saint anthony
# City 420 | tapes
# City 421 | sterling
# Record n/a
# City 422 | kruisfontein
# City 423 | luanda
# City 424 | havoysund
# Record n/a
# City 425 | zeya
# City 426 | togur
# City 427 | monrovia
# City 428 | bandarbeyla
# City 429 | kikwit
# City 430 | constitucion
# City 431 | malakal
# City 432 | san jose
# City 433 | bhag
# City 434 | bac lieu
# City 435 | dauphin
# City 436 | poltar
# City 437 | semnan
# City 438 | cap malheureux
# City 439 | barcelona
# City 440 | buzmeyin
# City 441 | lavrentiya
# City 442 | butterworth
# City 443 | west fargo
# City 444 | anadyr
# City 445 | nabire
# City 446 | sulangan
# City 447 | bay roberts
# City 448 | harper
# City 449 | zalari
# City 450 | trapani
# City 451 | nantai
# City 452 | nioro
# City 453 | flinders
# City 454 | winslow
# City 455 | maceio
# City 456 | lorengau
# City 457 | general pico
# City 458 | kawalu
# City 459 | saldanha
# City 460 | brasilia
# City 461 | kanadukathan
# Record n/a
# City 462 | krasnyy yar
# City 463 | san andres
# City 464 | uren
# City 465 | ofaqim
# Record n/a
# City 466 | ashqelon
# City 467 | katobu
# City 468 | ayia galini
# City 469 | acapulco
# City 470 | iskateley
# City 471 | rocha
# City 472 | arlit
# Record n/a
# City 473 | sinnamary
# City 474 | yeppoon
# City 475 | celestun
# City 476 | kieta
# City 477 | pyapon
# City 478 | sri aman
# City 479 | tarakan
# City 480 | fort nelson
# City 481 | fairbanks
# City 482 | belyy yar
# City 483 | pontefract
# City 484 | paamiut
# City 485 | urucui
# Record n/a
# City 486 | katsuura
# City 487 | neryungri
# City 488 | sitka
# Record n/a
# Record n/a
# Record n/a
# Record n/a
# City 489 | teya
# City 490 | caravelas
# City 491 | severo-yeniseyskiy
# City 492 | arkhangelsk
# City 493 | borovskoy
# City 494 | hualmay
# City 495 | shahr-e kord
# City 496 | yarkovo
# Record n/a
# City 497 | singaraja
# City 498 | deputatskiy
# City 499 | gat
# City 500 | nador
# City 501 | odienne
# City 502 | denpasar
# City 503 | pontes e lacerda
# Record n/a
# City 504 | paraiso
# Record n/a
# City 505 | rio bueno
# Record n/a
# City 506 | san quintin
# City 507 | odweyne
# City 508 | zhangye
# City 509 | digha
# City 510 | svetlyy
# City 511 | oum hadjer
# City 512 | fomboni
# City 513 | sabha
# City 514 | muros
# City 515 | tupiza
# City 516 | basco
# City 517 | los llanos de aridane
# Record n/a
# Record n/a
# Record n/a
# Record n/a
# City 518 | biak
# City 519 | juneau
# City 520 | becerril
# City 521 | uyuni
# City 522 | rudnogorsk
# Record n/a
# City 523 | petropavlovsk-kamchatskiy
# City 524 | jalu
# City 525 | mount pleasant
# City 526 | bardiyah
# Record n/a
# City 527 | alvaraes
# City 528 | krasnoselkup
# City 529 | ngunguru
# City 530 | iquique
# City 531 | bongandanga
# City 532 | harboore
# City 533 | dongsheng
# Record n/a
# City 534 | jibuti
# City 535 | muhos
# Record n/a
# City 536 | san carlos de bariloche
# City 537 | grand gaube
# Record n/a
# City 538 | nyakahanga
# City 539 | yarim
# City 540 | vigrestad
# Record n/a
# City 541 | gazanjyk
# City 542 | vostok
# City 543 | port hedland
# City 544 | marzuq
# Complete!

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display the data
# Create weather dictionary from attributes in loop. Use this dictionary to create a pandas data frame.
weather_dictionary = {
                     "City ID": city_id,
                     "City": city_name,
                     "Country": country,
                     "Latitude": lat,
                     "Longitude": lng,
                     "Date": date,
                     "Max. Temperature (F)": max_temp,
                     "Cloudiness (%)": cloudiness,
                     "Humidity (%)": humidity,
                     "Wind Speed (mph)": wind_speed}

# Data Frame
weather_df = pd.DataFrame(weather_dictionary)
weather_df.head()
# Out:
#    City ID             City Country  Latitude  Longitude        Date  \
# 0   934322        Mahébourg      MU  -20.4081    57.7000  1592946000
# 1  3366880         Hermanus      ZA  -34.4187    19.2345  1592946000
# 2   964712  Plettenberg Bay      ZA  -34.0527    23.3716  1592946000
# 3    49747            Oddur      SO    4.1213    43.8894  1592946000
# 4  5122534        Jamestown      US   42.0970   -79.2353  1592946000
#
#    Max. Temperature (F)  Cloudiness (%)  Humidity (%)  Wind Speed (mph)
# 0                 72.03              39            80             13.04
# 1                 56.50              16            81              3.65
# 2                 60.69               3            57              4.29
# 3                 78.35              29            65             17.00
# 4                 72.00              95            83             14.65

# %%
# Per isntructions - For final notebook, save a csv of all retrieved data
weather_df.to_csv(r'output_data\weater_data.csv')
total_cities = len(weather_df)
total_cities
# Out:
# 544

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.sort_values("Humidity (%)", ascending=False)
# Out:
#      City ID      City Country  Latitude  Longitude        Date  \
# 541  2013279    Vostok      RU   46.4856   135.8833  1592946000
# 389  1308937     Mogok      MM   22.9167    96.5000  1592946000
# 143  1651810     Airai      TL   -8.9266   125.4092  1592946000
# 477  1735799  Sri Aman      MY    1.2376   111.4621  1592946000
# 286  1786855     Yatou      CN   37.1500   122.3833  1592946000
# ..       ...       ...     ...       ...        ...         ...
# 177   108410    Riyadh      SA   24.6877    46.7219  1592946000
# 471  2447513     Arlit      NE   18.7369     7.3853  1592946000
# 411  5509851   Pahrump      US   36.2083  -115.9839  1592946000
# 259  5287262   Buckeye      US   33.3703  -112.5838  1592946000
# 120  2381972     Adrar      MR   20.5022   -10.0711  1592946000
#
#      Max. Temperature (F)  Cloudiness (%)  Humidity (%)  Wind Speed (mph)
# 541                 52.92             100           100              3.80
# 389                 67.17             100           100              3.40
# 143                 56.46              41           100              3.80
# 477                 74.12             100            99              1.41
# 286                 70.92             100            98              3.29
# ..                    ...             ...           ...               ...
# 177                 90.28              50            10             12.46
# 471                 99.88               3             8              4.85
# 411                103.39               0             8             12.95
# 259                108.18               0             7             11.32
# 120                107.37              11             7             11.16
#
# [544 rows x 10 columns]

# %%
# AFTER SORTING BY DESCENDING HUMIDITY, THERE ARE NO VALUES THAT SHOW HUMIDITY OVER 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create scatter plot to showcase Temperature (F) vs. Latitude
plot_lat = weather_df['Latitude']
plot_temp = weather_df['Max. Temperature (F)']

plt.figure(figsize=(7,7))
plt.scatter(plot_lat, plot_temp)
plt.title('City Latitude vs. Max. Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)
plt.savefig('temp_vs_lat_scatter')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create scatter plot to showcase Humidity (%) vs. Latitude
plot_lat = weather_df['Latitude']
plot_hum = weather_df['Humidity (%)']

plt.figure(figsize=(7,7))
plt.scatter(plot_lat, plot_hum)
plt.title('City Latitude vs. Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig('hum_vs_lat_scatter')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create scatter plot to showcase Cloudiness (%) vs. Latitude
plot_lat = weather_df['Latitude']
plot_cloud = weather_df['Cloudiness (%)']

plt.figure(figsize=(7,7))
plt.scatter(plot_lat, plot_cloud)
plt.title('City Latitude vs. Cloudiness (%)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('cloud_vs_lat_scatter')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create scatter plot to showcase Wind Speed (mph) vs. Latitude
plot_lat = weather_df['Latitude']
plot_wind = weather_df['Wind Speed (mph)']

plt.figure(figsize=(7,7))
plt.scatter(plot_lat, plot_wind)
plt.title('City Latitude vs. Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('wind_vs_lat_scatter')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def lin_reg_plot(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
# Run linear regression on each relationship, separating them into... 
# ...Northern Hemisphere (greater than or equal to 0 degrees latitude) and...
# ...Southern Hemisphere (less than 0 degrees latitude)

# %%
# Create Northern Hemisphere DF
north_df = weather_df.loc[weather_df['Latitude'] >= 0,:]
north_df.head()
# Out:
#     City ID       City Country  Latitude  Longitude        Date  \
# 3     49747      Oddur      SO    4.1213    43.8894  1592946000
# 4   5122534  Jamestown      US   42.0970   -79.2353  1592946000
# 5   2514301      Mahon      ES   39.8885     4.2658  1592946000
# 8   1568574   Qui Nhon      VN   13.7667   109.2333  1592946000
# 10   587620   Viiratsi      EE   58.3600    25.6372  1592946000
#
#     Max. Temperature (F)  Cloudiness (%)  Humidity (%)  Wind Speed (mph)
# 3                  78.35              29            65             17.00
# 4                  72.00              95            83             14.65
# 5                  73.69               0            72              8.90
# 8                  80.20              88            85              3.47
# 10                 65.12               4            64              3.18

# %%
# Create Southern Hemisphere DF
south_df = weather_df.loc[weather_df['Latitude'] < 0,:]
south_df.head()
# Out:
#    City ID             City Country  Latitude  Longitude        Date  \
# 0   934322        Mahébourg      MU  -20.4081    57.7000  1592946000
# 1  3366880         Hermanus      ZA  -34.4187    19.2345  1592946000
# 2   964712  Plettenberg Bay      ZA  -34.0527    23.3716  1592946000
# 6  3466165         Cidreira      BR  -30.1811   -50.2056  1592946000
# 7  2083537            Wewak      PG   -3.5534   143.6268  1592946000
#
#    Max. Temperature (F)  Cloudiness (%)  Humidity (%)  Wind Speed (mph)
# 0                 72.03              39            80             13.04
# 1                 56.50              16            81              3.65
# 2                 60.69               3            57              4.29
# 6                 71.56               1            68              8.55
# 7                 79.11              85            83              6.35

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store lat and temp as x and y values
nlat_mean = round(north_df['Latitude'].astype('float').mean(), 2)
nlat_median = round(north_df['Latitude'].astype('float').median(), 2)
nlat_mode = round(north_df['Latitude'].astype('float').mode(), 2)

ntemp_mean = round(north_df['Max. Temperature (F)'].astype('float').mean(), 2)
ntemp_median = round(north_df['Max. Temperature (F)'].astype('float').median(), 2)
ntemp_mode = round(north_df['Max. Temperature (F)'].astype('float').mode(), 2)

x1_values = north_df['Latitude'].astype('float')
y1_values = north_df['Max. Temperature (F)'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x1_values, y1_values)
regress_values = x1_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(7,7))
plt.scatter(x1_values,y1_values)

# Plot regression line
plt.plot(x1_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.5507305215097111

# %%
print("This plot shows a moderate positive relationship.")
# Out:
# This plot shows a moderate positive relationship.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store lat and temp as x and y values
slat_mean = round(south_df['Latitude'].astype('float').mean(), 2)
slat_median = round(south_df['Latitude'].astype('float').median(), 2)
slat_mode = round(south_df['Latitude'].astype('float').mode(), 2)

stemp_mean = round(south_df['Max. Temperature (F)'].astype('float').mean(), 2)
stemp_median = round(south_df['Max. Temperature (F)'].astype('float').median(), 2)
stemp_mode = round(south_df['Max. Temperature (F)'].astype('float').mode(), 2)

x2_values = south_df['Latitude'].astype('float')
y2_values = south_df['Max. Temperature (F)'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x2_values, y2_values)
regress_values = x2_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(7,7))
plt.scatter(x2_values,y2_values)

# Plot regression line
plt.plot(x2_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.6498861726235329

# %%
print("This plot shows a moderate positive relationship.")
# Out:
# This plot shows a moderate positive relationship.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store lat and hum as x and y values
nlat_mean = round(north_df['Latitude'].astype('float').mean(), 2)
nlat_median = round(north_df['Latitude'].astype('float').median(), 2)
nlat_mode = round(north_df['Latitude'].astype('float').mode(), 2)

nhum_mean = round(north_df['Humidity (%)'].astype('float').mean(), 2)
nhum_median = round(north_df['Humidity (%)'].astype('float').median(), 2)
nhum_mode = round(north_df['Humidity (%)'].astype('float').mode(), 2)

x1_values = north_df['Latitude'].astype('float')
y3_values = north_df['Humidity (%)'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x1_values, y3_values)
regress_values = x1_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(7,7))
plt.scatter(x1_values,y3_values)

# Plot regression line
plt.plot(x1_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.0032707317753953463

# %%
print("This plot shows no linear relationship.")
# Out:
# This plot shows no linear relationship.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store lat and hum as x and y values
slat_mean = round(south_df['Latitude'].astype('float').mean(), 2)
slat_median = round(south_df['Latitude'].astype('float').median(), 2)
slat_mode = round(south_df['Latitude'].astype('float').mode(), 2)

shum_mean = round(south_df['Humidity (%)'].astype('float').mean(), 2)
shum_median = round(south_df['Humidity (%)'].astype('float').median(), 2)
shum_mode = round(south_df['Humidity (%)'].astype('float').mode(), 2)

x2_values = south_df['Latitude'].astype('float')
y4_values = south_df['Humidity (%)'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x2_values, y4_values)
regress_values = x2_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(7,7))
plt.scatter(x2_values,y4_values)

# Plot regression line
plt.plot(x2_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.005559738086525683

# %%
print("This plot shows no linear relationship.")
# Out:
# This plot shows no linear relationship.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store lat and clo as x and y values
nlat_mean = round(north_df['Latitude'].astype('float').mean(), 2)
nlat_median = round(north_df['Latitude'].astype('float').median(), 2)
nlat_mode = round(north_df['Latitude'].astype('float').mode(), 2)

nclo_mean = round(north_df['Cloudiness (%)'].astype('float').mean(), 2)
nclo_median = round(north_df['Cloudiness (%)'].astype('float').median(), 2)
nclo_mode = round(north_df['Cloudiness (%)'].astype('float').mode(), 2)

x1_values = north_df['Latitude'].astype('float')
y5_values = north_df['Cloudiness (%)'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x1_values, y5_values)
regress_values = x1_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(7,7))
plt.scatter(x1_values,y5_values)

# Plot regression line
plt.plot(x1_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.00870578234409641

# %%
print("This plot shows no linear relationship.")
# Out:
# This plot shows no linear relationship.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store lat and clo as x and y values
slat_mean = round(south_df['Latitude'].astype('float').mean(), 2)
slat_median = round(south_df['Latitude'].astype('float').median(), 2)
slat_mode = round(south_df['Latitude'].astype('float').mode(), 2)

sclo_mean = round(south_df['Cloudiness (%)'].astype('float').mean(), 2)
sclo_median = round(south_df['Cloudiness (%)'].astype('float').median(), 2)
sclo_mode = round(south_df['Cloudiness (%)'].astype('float').mode(), 2)

x2_values = south_df['Latitude'].astype('float')
y6_values = south_df['Cloudiness (%)'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x2_values, y6_values)
regress_values = x2_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(7,7))
plt.scatter(x2_values,y6_values)

# Plot regression line
plt.plot(x2_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.title('Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 5.168913366632018e-05

# %%
print("This plot shows no linear relationship.")
# Out:
# This plot shows no linear relationship.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store lat and clo as x and y values
nlat_mean = round(north_df['Latitude'].astype('float').mean(), 2)
nlat_median = round(north_df['Latitude'].astype('float').median(), 2)
nlat_mode = round(north_df['Latitude'].astype('float').mode(), 2)

nwin_mean = round(north_df['Wind Speed (mph)'].astype('float').mean(), 2)
nwin_median = round(north_df['Wind Speed (mph)'].astype('float').median(), 2)
nwin_mode = round(north_df['Wind Speed (mph)'].astype('float').mode(), 2)

x1_values = north_df['Latitude'].astype('float')
y7_values = north_df['Wind Speed (mph)'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x1_values, y7_values)
regress_values = x1_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(7,7))
plt.scatter(x1_values,y7_values)

# Plot regression line
plt.plot(x1_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.0025232299545640104

# %%
print("This plot shows no linear relationship.")
# Out:
# This plot shows no linear relationship.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store lat and clo as x and y values
slat_mean = round(south_df['Latitude'].astype('float').mean(), 2)
slat_median = round(south_df['Latitude'].astype('float').median(), 2)
slat_mode = round(south_df['Latitude'].astype('float').mode(), 2)

swin_mean = round(south_df['Wind Speed (mph)'].astype('float').mean(), 2)
swin_median = round(south_df['Wind Speed (mph)'].astype('float').median(), 2)
swin_mode = round(south_df['Wind Speed (mph)'].astype('float').mode(), 2)

x2_values = south_df['Latitude'].astype('float')
y8_values = south_df['Wind Speed (mph)'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x2_values, y8_values)
regress_values = x2_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.figure(figsize=(7,7))
plt.scatter(x2_values,y8_values)

# Plot regression line
plt.plot(x2_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.004134111358410395

# %%
print("This plot shows no linear relationship.")
# Out:
# This plot shows no linear relationship.
